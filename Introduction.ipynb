# %% [markdown]
# # Exam tips - Ghee do van rossum

# %% [raw]
# Exam Tips.
# Keywords, Objects, Function, Module, Method.
#
# keyword.kwlist
# help(keyword)
# help(objects, function, module)
# help(object/module.method)
#
# dir(object, module)
#
# keyword?
# function?
# Module?
# Object?

# %% [markdown]
# # Introduction

# %%
print("hello world") #comment
# Out:
# hello world

# %%
a = 10
b = 20
print(a)
print(b)
# Out:
# 10
# 20

# %%
a = 20 ; b= 30
print(a,b)
# Out:
# 20 30

# %%
r = "\u20b9"
r
# Out:
# '₹'

# %%
p1 = "m" in "mumbai" #in operator
print(p1)
# Out:
# True

# %%
p2 = """hello in the world""" #use """ or ''' or ' or " inside string
p2
# Out:
# 'hello in the world'

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
a = 20
print(type(a)) # data type of the object
print(id(a))
b = 'hello'
print(type(b))
print(id(b)) # virtual address of the object
# Out:
# <class 'int'>
# 140724435465736
# <class 'str'>
# 1717554808704

# %%
print(dir(__builtins__))
# Out:
# ['ArithmeticError', 'AssertionError', 'AttributeError', 'BaseException', 'BaseExceptionGroup', 'BlockingIOError', 'BrokenPipeError', 'BufferError', 'BytesWarning', 'ChildProcessError', 'ConnectionAbortedError', 'ConnectionError', 'ConnectionRefusedError', 'ConnectionResetError', 'DeprecationWarning', 'EOFError', 'Ellipsis', 'EncodingWarning', 'EnvironmentError', 'Exception', 'ExceptionGroup', 'False', 'FileExistsError', 'FileNotFoundError', 'FloatingPointError', 'FutureWarning', 'GeneratorExit', 'IOError', 'ImportError', 'ImportWarning', 'IndentationError', 'IndexError', 'InterruptedError', 'IsADirectoryError', 'KeyError', 'KeyboardInterrupt', 'LookupError', 'MemoryError', 'ModuleNotFoundError', 'NameError', 'None', 'NotADirectoryError', 'NotImplemented', 'NotImplementedError', 'OSError', 'OverflowError', 'PendingDeprecationWarning', 'PermissionError', 'ProcessLookupError', 'PythonFinalizationError', 'RecursionError', 'ReferenceError', 'ResourceWarning', 'RuntimeError', 'RuntimeWarni
# ...

# %%
a = b = c = 10
print(a,b,c)
# Out:
# 10 10 10

# %%
a = 10 ;b = 20
print(a,b)
print(id(a))
print(id(b)) #values from -5 to 256(2 to the power) are predefined inside the loop after 256 is it different.
# special case a,b = 10 doesn't work but a;b = 10 does work
# Out:
# 10 20
# 140724435465416
# 140724435465736

# %%
print(dir(int),end = ',')
# Out:
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'as_integer_ratio', 'bit_count', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'is_integer', 'numerator', 'real', 'to_bytes'],

# %% [markdown]
# # Indentation

# %%
s = 0
if s ==0:
    print("sensor is off")
else:
    print("sensor is on")
print("Done") # indentation is very important while working with python
# Out:
# sensor is off
# Done

# %%
print(__name__)
# Out:
# __main__

# %%
if __name__ == "__main__":
    print("Main file where program is running from")
# Out:
# Main file where program is running from

# %% [markdown]
# # Input functions and booleans and operators

# %%
r1 = input("Enter subject:") # takes only strings
print(r1)
# Out:
# Enter subject: PDS
# PDS

# %%
r2 = int(input("Enter marks:"))
print(r2)
# Out:
# Enter marks: 100
# 100

# %%
print(len(r1)) #length of the string
print(r2+10)
# Out:
# 3
# 110

# %%
"78" + "45" #string concatenation
# Out:
# '7845'

# %%
10 + 10 #just addition
# Out:
# 20

# %%
int("88") + 10 #explicit conversion
# Out:
# 98

# %%
float(10) + 5
# Out:
# 15.0

# %%
print(bool(1))
print(bool(0))
# Out:
# True
# False

# %%
print(bool(''))
print(bool('False'))
# Out:
# False
# True

# %%
bool(int('0'))
# Out:
# False

# %%
2/3
# Out:
# 0.6666666666666666

# %%
3-2
# Out:
# 1

# %%
3%6
# Out:
# 3

# %%
3*6
# Out:
# 18

# %%
3**5
# Out:
# 243

# %%
'hello'*3
# Out:
# 'hellohellohello'

# %%
not(True)
# Out:
# False

# %%
not(False)
# Out:
# True

# %%
not(5)
# Out:
# False

# %%
a = 1+3.14j
a
print(type(a))
# Out:
# <class 'complex'>

# %%
a.imag #imaginary number
# Out:
# 3.14

# %%
a.real #real number
# Out:
# 1.0

# %%
a.conjugate() # opposite of something
# Out:
# (1-3.14j)

# %% [markdown]
# # Miscellaneous

# %%
print(type(print)) #print does not return anything where it just displays.
# Out:
# <class 'builtin_function_or_method'>

# %%
print1 = "hello"
print("hi")
# Out:
# hi

# %% [raw]
# Note: Do not use inbuilt function like print as string and string as function or else it will lead to callable issue.

# %% [raw]
# -> Local defined variable
# -> Globally defined variable
# -> Non Locally defined inside nested functions
# -> Builtin functions
